# %%
import pandas as pd
import numpy as np 
import nltk

# %%
import calendar 

def getData(month,day):
    url = "https://raw.githubusercontent.com/thepanacealab/covid19_twitter/master/dailies/2020-"+month+"-"+str(day)+"/2020-"+month+"-"+str(day)+"_top1000trigrams.csv"
    df = pd.read_csv(url)
    df = df[:550]
    df['date'] = calendar.month_name[int(month)] + " "+str(day) + ", 2020"
    return df

def getData2(month,day):
    url = "https://raw.githubusercontent.com/thepanacealab/covid19_twitter/master/dailies/2020-"+month+"-"+str(day)+"/2020-"+month+"-"+str(day)+"_top1000triigrams.csv"
    df = pd.read_csv(url)
    df = df[:550]
    df['date'] = calendar.month_name[int(month)] + " "+str(day) + ", 2020"
    return df

apr23 = getData('04',23)
apr24 = getData('04',24)
apr25 = getData('04',25)
apr26 = getData('04',26)
apr27 = getData('04',27)
apr28 = getData('04',28)
apr29 = getData('04',29)
apr30 = getData('04',30)

may01 = getData('05','01')
may02 = getData('05','02')
may03 = getData('05','03')
may04 = getData('05','04')
may05 = getData('05','05')
may06 = getData('05','06')
may07 = getData('05','07')
may08 = getData('05','08')
may09 = getData('05','09')
may10 = getData('05','10')
may11 = getData('05','11')
may12 = getData('05','12')
may13 = getData('05','13')
may14 = getData('05','14')
may15 = getData('05','15')
may16 = getData('05','16')
may17 = getData('05','17')
may18 = getData('05','18')

may19 = getData('05',19)
may20 = getData2('05',20)
may21 = getData('05',21)
may22 = getData('05',22)
may23 = getData('05',23)
may24 = getData('05',24)
may25 = getData('05',25)
may26 = getData('05',26)
may27 = getData('05',27)
may28 = getData('05',28)
may29 = getData('05',29)
may30 = getData('05',30)
may31 = getData('05',31)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
june01 = getData('06','01')
june02 = getData('06','02')
june03 = getData('06','03')
june04 = getData('06','04')
june05 = getData('06','05')
june06 = getData('06','06')
june07 = getData('06','07')
june08 = getData('06','08')
june09 = getData('06','09')
june10 = getData('06','10')
june11 = getData('06','11')
june12 = getData('06','12')
june13 = getData('06','13')
june14 = getData('06','14')
june15 = getData('06','15')
june16 = getData('06','16')
june17 = getData('06','17')
june18 = getData('06','18')
june19 = getData('06','19')
june20 = getData('06','20')
june21 = getData('06','21')
june22 = getData('06','22')
june23 = getData('06','23')
june24 = getData('06','24')
june25 = getData('06','25')
june26 = getData('06','26')
june27 = getData('06','27')
june28 = getData('06','28')
june29 = getData('06','29')
june30 = getData('06','30')

# %%
july01 = getData('07','01')
july02 = getData('07','02')
july03 = getData('07','03')
july04 = getData('07','04')
july05 = getData('07','05')
july06 = getData('07','06')
july07 = getData('07','07')
july08 = getData('07','08')
july09 = getData('07','09')
july10 = getData('07','10')
july11 = getData('07','11')
july12 = getData('07','12')
july13 = getData('07','13')
july14 = getData('07','14')
july15 = getData('07','15')
july16 = getData('07','16')
july17 = getData('07','17')
july18 = getData('07','18')
july19 = getData('07','19')
july20 = getData('07','20')
july21 = getData('07','21')
july22 = getData('07','22')
july23 = getData('07','23')
july24 = getData('07','24')
july25 = getData('07','25')
july26 = getData('07','26')
july27 = getData('07','27')
july28 = getData('07','28')
july29 = getData('07','29')
july30 = getData('07','30')
july31 = getData('07','31')

# %%
aug01 = getData('08','01')
aug02 = getData('08','02')
aug03 = getData('08','03')
aug04 = getData('08','04')
aug05 = getData('08','05')
aug06 = getData('08','06')
aug07 = getData('08','07')
aug08 = getData('08','08')
aug09 = getData('08','09')
aug10 = getData('08','10')
aug11 = getData('08','11')
aug12 = getData('08','12')
aug13 = getData('08','13')
aug14 = getData('08','14')
aug15 = getData('08','15')
aug16 = getData('08','16')
aug17 = getData('08','17')
aug18 = getData('08','18')
aug19 = getData('08','19')
aug20 = getData('08','20')
aug21 = getData('08','21')
aug22 = getData('08','22')
aug23 = getData('08','23')
aug24 = getData('08','24')
aug25 = getData('08','25')
aug26 = getData('08','26')
aug27 = getData('08','27')
aug28 = getData('08','28')
aug29 = getData('08','29')
aug30 = getData('08','30')
aug31 = getData('08','31')

# %%
sep01 = getData('09','01')
sep02 = getData('09','02')
sep03 = getData('09','03')
sep04 = getData('09','04')
sep05 = getData('09','05')
sep06 = getData('09','06')
sep07 = getData('09','07')
sep08 = getData('09','08')
sep09 = getData('09','09')
sep10 = getData('09','10')
sep11 = getData('09','11')
sep12 = getData('09','12')
sep13 = getData('09','13')
sep14 = getData('09','14')

# %%
sep15 = getData('09','15')
sep16 = getData('09','16')
sep17 = getData('09','17')
sep18 = getData('09','18')
sep19 = getData('09','19')
sep20 = getData('09','20')
sep21 = getData('09','21')
sep22 = getData('09','22')
sep23 = getData('09','23')
sep24 = getData('09','24')
sep25 = getData('09','25')
sep26 = getData('09','26')
sep27 = getData('09','27')
sep28 = getData('09','28')
sep29 = getData('09','29')
sep30 = getData('09','30')

# %%
oct01 = getData('10','01')
oct02 = getData('10','02')
oct03 = getData('10','03')
oct04 = getData('10','04')
oct05 = getData('10','05')
oct06 = getData('10','06')
oct07 = getData('10','07')
oct08 = getData('10','08')
oct09 = getData('10','09')
oct10 = getData('10','10')
oct11 = getData('10','11')
oct12 = getData('10','12')
oct13 = getData('10','13')
oct14 = getData('10','14')
oct15 = getData('10','15')
oct16 = getData('10','16')
oct17 = getData('10','17')
oct18 = getData('10','18')
oct19 = getData('10','19')
oct20 = getData('10','20')
oct21 = getData('10','21')
oct22 = getData('10','22')
oct23 = getData('10','23')
oct24 = getData('10','24')
oct25 = getData('10','25')
oct26 = getData('10','26')
oct27 = getData('10','27')
oct28 = getData('10','28')
oct29 = getData('10','29')
oct30 = getData('10','30')
oct31 = getData('10','31')

# %%
nov01 = getData('11','01')
nov02 = getData('11','02')
nov03 = getData('11','03')
nov04 = getData('11','04')
nov05 = getData('11','05')
nov06 = getData('11','06')
nov07 = getData('11','07')
nov08 = getData('11','08')
nov09 = getData('11','09')
nov10 = getData('11','10')
nov11 = getData('11','11')
nov12 = getData('11','12')
nov13 = getData('11','13')
nov14 = getData('11','14')
nov15 = getData('11','15')
nov16 = getData('11','16')
nov17 = getData('11','17')
nov18 = getData('11','18')
nov19 = getData('11','19')
nov20 = getData('11','20')
nov21 = getData('11','21')
nov22 = getData('11','22')
nov23 = getData('11','23')
nov24 = getData('11','24')
nov25 = getData('11','25')
nov26 = getData('11','26')
nov27 = getData('11','27')
nov28 = getData('11','28')
nov29 = getData('11','29')
nov30 = getData('11','30')

# %%
dec01 = getData('12','01')
dec02 = getData('12','02')
dec03 = getData('12','03')
dec04 = getData('12','04')
dec05 = getData('12','05')
dec06 = getData('12','06')
dec07 = getData('12','07')
dec08 = getData('12','08')
dec09 = getData('12','09')
dec10 = getData('12','10')
dec11 = getData('12','11')
dec12 = getData('12','12')
dec13 = getData('12','13')
dec14 = getData('12','14')
dec15 = getData('12','15')
dec16 = getData('12','16')
dec17 = getData('12','17')
dec18 = getData('12','18')
dec19 = getData('12','19')
dec20 = getData('12','20')
dec21 = getData('12','21')
dec22 = getData('12','22')
dec23 = getData('12','23')
dec24 = getData('12','24')
dec25 = getData('12','25')
dec26 = getData('12','26')
dec27 = getData('12','27')
dec28 = getData('12','28')
dec29 = getData('12','29')
dec30 = getData('12','30')
dec31 = getData('12','31')

# %%
def getData2(month,day):
    url = "https://raw.githubusercontent.com/thepanacealab/covid19_twitter/master/dailies/2021-"+month+"-"+str(day)+"/2021-"+month+"-"+str(day)+"_top1000trigrams.csv"
    #url2 = "https://github.com/thepanacealab/covid19_twitter/blob/master/dailies/2021-"+month+"-"+str(day)+"/2021-"+month+"-"+str(day)+"_top1000bigrams.csv"
    df = pd.read_csv(url)
    df = df[:550]
    df['date'] = calendar.month_name[int(month)] + " "+str(day) + ", 2021"
    return df

# %%
jan01 = getData2('01','01')
jan02 = getData2('01','02')
jan03 = getData2('01','03')
jan04 = getData2('01','04')
jan05 = getData2('01','05')
jan06 = getData2('01','06')
jan07 = getData2('01','07')
jan08 = getData2('01','08')
jan09 = getData2('01','09')
jan10 = getData2('01','10')
jan11 = getData2('01','11')
jan12 = getData2('01','12')
jan13 = getData2('01','13')
jan14 = getData2('01','14')
jan15 = getData2('01','15')
jan16 = getData2('01','16')
jan17 = getData2('01','17')
jan18 = getData2('01','18')
jan19 = getData2('01','19')
jan20 = getData2('01','20')
jan21 = getData2('01','21')
jan22 = getData2('01','22')
jan23 = getData2('01','23')
jan24 = getData2('01','24')
jan25 = getData2('01','25')
jan26 = getData2('01','26')
jan27 = getData2('01','27')
jan28 = getData2('01','28')
jan29 = getData2('01','29')
jan30 = getData2('01','30')
jan31 = getData2('01','31')
feb01 = getData2('02','01')

# %%
df = pd.concat([apr23,apr24,apr25,apr26,apr27,apr28,apr29,apr30,
               may01,may02,may03,may04,may05,may06,may07,may08,may09,may10,
               may11,may12,may13,may14,may15,may16,may17,may18,may19,may20,
               may21,may22,may23,may24,may25,may26,may27,may28,may29,may30,may31,
               june01,june02,june03,june04,june05,june06,june07,june08,june09,june10,
               june11,june12,june13,june14,june15,june16,june17,june18,june19,june20,
               june21,june22,june23,june24,june25,june26,june27,june28,june29,june30,
               july01,july02,july03,july04,july05,july06,july07,july08,july09,july10,
               july11,july12,july13,july14,july15,july16,july17,july18,july19,july20,
               july21,july22,july23,july24,july25,july26,july27,july28,july29,july30,july31,
               aug01,aug02,aug03,aug04,aug05,aug06,aug07,aug08,aug09,aug10,
               aug11,aug12,aug13,aug14,aug15,aug16,aug17,aug18,aug19,aug20,
               aug21,aug22,aug23,aug24,aug25,aug26,aug27,aug28,aug29,aug30,aug31,
               sep01,sep02,sep03,sep04,sep05,sep06,sep07,sep08,sep09,sep10,
               sep11,sep12,sep13,sep14,sep15,sep16,sep17,sep18,sep19,sep20,sep21,sep22,sep23,sep24,
               sep25,sep26,sep27,sep28,sep29,sep30,oct01,oct02,oct03,oct04,oct05,oct06,oct07,
               oct08,oct09,oct10,oct11,oct12,oct13,oct14,oct15,oct16,oct17,oct18,oct19,oct20,oct21,
               oct22,oct23,oct24,oct25,oct26,oct27,oct28,oct29,oct30,oct31,nov01,nov02,nov03,nov04,nov05,
               nov06,nov07,nov08,nov09,nov10,nov11,nov12,nov13,nov14,nov15,nov16,nov17,nov18,nov19,nov20,nov21,
               nov22,nov23,nov24,nov25,nov26,nov27,nov28,nov29,nov30,dec01,dec02,dec03,dec04,dec05,
               dec06,dec07,dec08,dec09,dec10,dec11,dec12,dec13,dec14,dec15,dec16,dec17,dec18,dec19,dec20,
               dec21,dec22,dec23,dec24,dec25,dec26,dec27,dec28,dec29,dec30,dec31,jan01,jan02,jan03,jan04,
               jan05,jan06,jan07,jan08,jan09,jan10,jan11,jan12,jan13,jan14,jan15,jan16,jan17,jan18,jan19,
               jan20,jan21,jan22,jan23,jan24,jan25,jan26,jan27,jan28,jan29,jan30,jan31,feb01])
df
# Out:
#                     gram counts               date
# 0      covid 19 pandemic   8036     April 23, 2020
# 1      href rel nofollow   4204     April 23, 2020
# 2         covid 19 cases   4161     April 23, 2020
# 3          true href rel   4130     April 23, 2020
# 4        covid 19 crisis   3860     April 23, 2020
# ..                   ...    ...                ...
# 545           enero 2021    240  February 01, 2021
# 546       vacuna curevac    240  February 01, 2021
# 547      plan vacunación    239  February 01, 2021
# 548  variant coronavirus    239  February 01, 2021
# 549           know covid    238  February 01, 2021
#
# [156750 rows x 3 columns]

# %%
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud 
from matplotlib import pyplot as plt

stopwords = set(stopwords.words('english'))
stopwords.update(["br", "href"])
textt = " ".join(review for review in df.gram)
wordcloud = WordCloud(stopwords=stopwords).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df.to_csv('./twitterData.csv',index=False)

# %%
df['gram'].unique
# Out:
# <bound method Series.unique of 0        covid 19 pandemic
# 1        href rel nofollow
# 2           covid 19 cases
# 3            true href rel
# 4          covid 19 crisis
#               ...
# 545             enero 2021
# 546         vacuna curevac
# 547        plan vacunación
# 548    variant coronavirus
# 549             know covid
# Name: gram, Length: 156750, dtype: object>

# %%
df['gram'].unique()
# Out:
# array(['covid 19 pandemic', 'href rel nofollow', 'covid 19 cases', ...,
#        'home workers', '231 million', 'vacuna curevac'], dtype=object)

# %%
df['counts'] = df['counts'].astype(float)

# %%
from textblob import TextBlob
df['polarity'] = df['gram'].apply(lambda x: TextBlob(x).polarity)
df['subjective'] = df['gram'].apply(lambda x: TextBlob(x).subjectivity)

# %%
df
# Out:
#                     gram  counts               date
# 0      covid 19 pandemic  8036.0     April 23, 2020
# 1      href rel nofollow  4204.0     April 23, 2020
# 2         covid 19 cases  4161.0     April 23, 2020
# 3          true href rel  4130.0     April 23, 2020
# 4        covid 19 crisis  3860.0     April 23, 2020
# ..                   ...     ...                ...
# 545           enero 2021   240.0  February 01, 2021
# 546       vacuna curevac   240.0  February 01, 2021
# 547      plan vacunación   239.0  February 01, 2021
# 548  variant coronavirus   239.0  February 01, 2021
# 549           know covid   238.0  February 01, 2021
#
# [156750 rows x 3 columns]

# %%
gram_list = df['gram'].values
type(gram_list)
# Out:
# numpy.ndarray

# %%
df
# Out:
#                     gram  counts               date
# 0      covid 19 pandemic  8036.0     April 23, 2020
# 1      href rel nofollow  4204.0     April 23, 2020
# 2         covid 19 cases  4161.0     April 23, 2020
# 3          true href rel  4130.0     April 23, 2020
# 4        covid 19 crisis  3860.0     April 23, 2020
# ..                   ...     ...                ...
# 545           enero 2021   240.0  February 01, 2021
# 546       vacuna curevac   240.0  February 01, 2021
# 547      plan vacunación   239.0  February 01, 2021
# 548  variant coronavirus   239.0  February 01, 2021
# 549           know covid   238.0  February 01, 2021
#
# [156750 rows x 3 columns]

# %% [markdown]
# # MonkeyLearn API Sentiment Analysis

# %%
from monkeylearn import MonkeyLearn

def getSentiment(data):
    ml = MonkeyLearn('cc8b08eec7064594f00e8ae2292d8304eb3a8f65')
    model_id = 'cl_rZ2P7hbs'
    data = [data]
    result = ml.classifiers.classify(model_id, data)
    df['sentiment'] = ((result.body[0]['classifications'][0]['tag_name']))
    df['sentiment_confidence'] = ((result.body[0]['classifications'][0]['confidence']))
    
    
df
# Out:
#                     gram  counts               date
# 0      covid 19 pandemic  8036.0     April 23, 2020
# 1      href rel nofollow  4204.0     April 23, 2020
# 2         covid 19 cases  4161.0     April 23, 2020
# 3          true href rel  4130.0     April 23, 2020
# 4        covid 19 crisis  3860.0     April 23, 2020
# ..                   ...     ...                ...
# 545           enero 2021   240.0  February 01, 2021
# 546       vacuna curevac   240.0  February 01, 2021
# 547      plan vacunación   239.0  February 01, 2021
# 548  variant coronavirus   239.0  February 01, 2021
# 549           know covid   238.0  February 01, 2021
#
# [156750 rows x 3 columns]

# %%
import json
import pandas as pd
import numpy as np
from sklearn import metrics, manifold## for processing
import re
import nltk## for plotting
import matplotlib.pyplot as plt
import seaborn as sns## for w2v
import gensim
import gensim.downloader as gensim_api## for bert
import transformers

# %%
from textblob import TextBlob
df['polarity'] = df['gram'].apply(lambda x: TextBlob(x).polarity)
df['subjective'] = df['gram'].apply(lambda x: TextBlob(x).subjectivity)
df
# Out:
#                     gram  counts               date  polarity  subjective
# 0      covid 19 pandemic  8036.0     April 23, 2020      0.00        0.00
# 1      href rel nofollow  4204.0     April 23, 2020      0.00        0.00
# 2         covid 19 cases  4161.0     April 23, 2020      0.00        0.00
# 3          true href rel  4130.0     April 23, 2020      0.35        0.65
# 4        covid 19 crisis  3860.0     April 23, 2020      0.00        0.00
# ..                   ...     ...                ...       ...         ...
# 545           enero 2021   240.0  February 01, 2021      0.00        0.00
# 546       vacuna curevac   240.0  February 01, 2021      0.00        0.00
# 547      plan vacunación   239.0  February 01, 2021      0.00        0.00
# 548  variant coronavirus   239.0  February 01, 2021      0.00        0.00
# 549           know covid   238.0  February 01, 2021      0.00        0.00
#
# [156750 rows x 5 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
from sklearn.pipeline import make_pipeline
tfidf_vectorizer = TfidfVectorizer(stop_words=stoplist, ngram_range=(2,3))
nmf = NMF(n_components=3)
pipe = make_pipeline(tfidf_vectorizer, nmf)
pipe.fit(df['gram'])
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += ", ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()
print_top_words(nmf, tfidf_vectorizer.get_feature_names(), n_top_words=3)
# Out:
# Topic #0: covid 19, casos covid, 19 via
# Topic #1: positive covid, tested positive, positive coronavirus
# Topic #2: new cases, cases covid, cases covid19

# %%
from sklearn.decomposition import LatentDirichletAllocation
tfidf_vectorizer = TfidfVectorizer(stop_words=stoplist, ngram_range=(2,3))
lda = LatentDirichletAllocation(n_components=3)
pipe = make_pipeline(tfidf_vectorizer, lda)
pipe.fit(df['gram'])
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += ", ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()
print_top_words(lda, tfidf_vectorizer.get_feature_names(), n_top_words=3)
# Out:
# Topic #0: covid 19, tested positive, stay home
# Topic #1: coronavirus pandemic, new york, cases covid
# Topic #2: covid 19, new cases, positive covid

# %%
df_vander = df[['gram','counts','date']]
df_vander
# Out:
#                     gram  counts               date
# 0      covid 19 pandemic  8036.0     April 23, 2020
# 1      href rel nofollow  4204.0     April 23, 2020
# 2         covid 19 cases  4161.0     April 23, 2020
# 3          true href rel  4130.0     April 23, 2020
# 4        covid 19 crisis  3860.0     April 23, 2020
# ..                   ...     ...                ...
# 545           enero 2021   240.0  February 01, 2021
# 546       vacuna curevac   240.0  February 01, 2021
# 547      plan vacunación   239.0  February 01, 2021
# 548  variant coronavirus   239.0  February 01, 2021
# 549           know covid   238.0  February 01, 2021
#
# [156750 rows x 3 columns]

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\chris\AppData\Roaming\nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sentimentAnalyzer = SentimentIntensityAnalyzer()

# %%
df
# Out:
#                     gram  counts               date sentiment_label
# 0      covid 19 pandemic  8036.0     April 23, 2020        negative
# 1      href rel nofollow  4204.0     April 23, 2020        negative
# 2         covid 19 cases  4161.0     April 23, 2020        negative
# 3          true href rel  4130.0     April 23, 2020        positive
# 4        covid 19 crisis  3860.0     April 23, 2020        negative
# ..                   ...     ...                ...             ...
# 545           enero 2021   240.0  February 01, 2021        negative
# 546       vacuna curevac   240.0  February 01, 2021        negative
# 547      plan vacunación   239.0  February 01, 2021        negative
# 548  variant coronavirus   239.0  February 01, 2021        negative
# 549           know covid   238.0  February 01, 2021        negative
#
# [156750 rows x 4 columns]

# %%
polarity = sentimentAnalyzer.polarity_scores(text)
polarity
# Out:
# {'neg': 0.403, 'neu': 0.427, 'pos': 0.17, 'compound': -0.6565}

# %%
text = "This was a terrible movie. It was very funny and I hated it."
count = 0
def getSentiment(text):
    helper = (sentimentAnalyzer.polarity_scores(text))
    sentiment = helper['compound']
    if(sentiment >= 0.05):
        return "positive"
    else:
        return "negative"

# %%
helper = list(df['gram'])
res = []
for x in helper:
    call = (getSentiment(x))
    res.append(call)

# %%
from collections import Counter

d = Counter(res)
x = "positive"
y = "negative"
#z = "neutral"
print('{} has occurred {} times'.format(x, d[x]))
print('{} has occurred {} times'.format(y, d[y]))
#print('{} has occurred {} times'.format(z, d[z]))
# Out:
# positive has occurred 14037 times
# negative has occurred 142713 times

# %%
df['sentiment_label'] = res
del df['sentiment__positive']
df
# Out:
#                     gram  counts               date sentiment_label
# 0      covid 19 pandemic  8036.0     April 23, 2020        negative
# 1      href rel nofollow  4204.0     April 23, 2020        negative
# 2         covid 19 cases  4161.0     April 23, 2020        negative
# 3          true href rel  4130.0     April 23, 2020        positive
# 4        covid 19 crisis  3860.0     April 23, 2020        negative
# ..                   ...     ...                ...             ...
# 545           enero 2021   240.0  February 01, 2021        negative
# 546       vacuna curevac   240.0  February 01, 2021        negative
# 547      plan vacunación   239.0  February 01, 2021        negative
# 548  variant coronavirus   239.0  February 01, 2021        negative
# 549           know covid   238.0  February 01, 2021        negative
#
# [156750 rows x 4 columns]

# %%
df = pd.concat([df,pd.get_dummies(df['sentiment_label'], prefix='sentiment_')],axis=1)
df
# Out:
#                     gram  counts               date sentiment_label  \
# 0      covid 19 pandemic  8036.0     April 23, 2020        negative
# 1      href rel nofollow  4204.0     April 23, 2020        negative
# 2         covid 19 cases  4161.0     April 23, 2020        negative
# 3          true href rel  4130.0     April 23, 2020        positive
# 4        covid 19 crisis  3860.0     April 23, 2020        negative
# ..                   ...     ...                ...             ...
# 545           enero 2021   240.0  February 01, 2021        negative
# 546       vacuna curevac   240.0  February 01, 2021        negative
# 547      plan vacunación   239.0  February 01, 2021        negative
# 548  variant coronavirus   239.0  February 01, 2021        negative
# 549           know covid   238.0  February 01, 2021        negative
#
#      sentiment__negative  sentiment__positive
# 0                      1                    0
# 1                      1                    0
# 2                      1                    0
# 3                      0                    1
# 4                      1                    0
# ..                   ...                  ...
# 545                    1                    0
# 546                    1                    0
# 547                    1                    0
# 548                    1                    0
# 549                    1                    0
#
# [156750 rows x 6 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
 
sns.catplot(x="sentiment_label", kind="count", palette="rainbow_r", data=df)

# %% [markdown]
# # Twitter API Key: UDvi5EebEM9DHUQ24TQbqvKll
# # Twitter API Key Sceret: dJAQpW8S1JNUxFTWYKMadATem2H9sj4Z5TIs5ZA8qg1oDwNATr
# # Bearer Token: AAAAAAAAAAAAAAAAAAAAABAIJwEAAAAA9kv0%2FJUpFa%2Fik0m3JQWpfUgrwFg%3DzDN05uHdQBlKupgSiJyC7sUZJ3p5GrOpJCDrQciTVsjfAyAeOi
# # Twitter Access Token: 1326348638839332871-Cr6NSeDxOPVx76kC3d7deWuoffo84Y
# # Twitter Access Token Secret: zDyXdiCF0X7lBR20FMlVkMShSm49FIpiaS4vlnrQBqfG5

# %%
df
# Out:
#                     gram  counts               date sentiment_label  \
# 0      covid 19 pandemic  8036.0     April 23, 2020        negative
# 1      href rel nofollow  4204.0     April 23, 2020        negative
# 2         covid 19 cases  4161.0     April 23, 2020        negative
# 3          true href rel  4130.0     April 23, 2020        positive
# 4        covid 19 crisis  3860.0     April 23, 2020        negative
# ..                   ...     ...                ...             ...
# 545           enero 2021   240.0  February 01, 2021        negative
# 546       vacuna curevac   240.0  February 01, 2021        negative
# 547      plan vacunación   239.0  February 01, 2021        negative
# 548  variant coronavirus   239.0  February 01, 2021        negative
# 549           know covid   238.0  February 01, 2021        negative
#
#      sentiment__negative  sentiment__positive
# 0                      1                    0
# 1                      1                    0
# 2                      1                    0
# 3                      0                    1
# 4                      1                    0
# ..                   ...                  ...
# 545                    1                    0
# 546                    1                    0
# 547                    1                    0
# 548                    1                    0
# 549                    1                    0
#
# [156750 rows x 6 columns]

# %%
dates = df.groupby(['date']).sum()
dates.reset_index(level=0, inplace=True)
dates
# Out:
#                    date    counts  sentiment__negative  sentiment__positive
# 0        April 23, 2020  295066.0                500.0                 50.0
# 1        April 24, 2020  284960.0                488.0                 62.0
# 2        April 25, 2020  274456.0                505.0                 45.0
# 3        April 26, 2020  274461.0                506.0                 44.0
# 4        April 27, 2020  287784.0                496.0                 54.0
# ..                  ...       ...                  ...                  ...
# 280  September 26, 2020  454963.0                518.0                 32.0
# 281  September 27, 2020  322797.0                505.0                 45.0
# 282  September 28, 2020  507882.0                506.0                 44.0
# 283  September 29, 2020  535237.0                500.0                 50.0
# 284  September 30, 2020  450353.0                502.0                 48.0
#
# [285 rows x 4 columns]

# %%
dates.columns
# Out:
# Index(['date', 'counts', 'sentiment__negative', 'sentiment__positive'], dtype='object')

# %%
dates['date'] = pd.to_datetime(dates.date)
dates.sort_values(by=['date'])
# Out:
#           date    counts  sentiment__negative  sentiment__positive
# 0   2020-04-23  295066.0                500.0                 50.0
# 1   2020-04-24  284960.0                488.0                 62.0
# 2   2020-04-25  274456.0                505.0                 45.0
# 3   2020-04-26  274461.0                506.0                 44.0
# 4   2020-04-27  287784.0                496.0                 54.0
# ..         ...       ...                  ...                  ...
# 98  2021-01-28  470742.0                501.0                 49.0
# 99  2021-01-29  467052.0                508.0                 42.0
# 100 2021-01-30  328594.0                520.0                 30.0
# 101 2021-01-31  339011.0                510.0                 40.0
# 70  2021-02-01  419169.0                501.0                 49.0
#
# [285 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(10, 10)})
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.ticklabel_format(axis='both', style='plain')
import seaborn as sns

sns.lineplot(x="date", y="counts", data=dates)
plt.xticks(rotation=45)
plt.title('Coronavirus Twitter Data By Date')
plt.show()

# %%
dates.to_csv('./twittercounts.csv',index=False)

# %%
dates
# Out:
#           date    counts  sentiment__negative  sentiment__positive
# 0   2020-04-23  295066.0                500.0                 50.0
# 1   2020-04-24  284960.0                488.0                 62.0
# 2   2020-04-25  274456.0                505.0                 45.0
# 3   2020-04-26  274461.0                506.0                 44.0
# 4   2020-04-27  287784.0                496.0                 54.0
# ..         ...       ...                  ...                  ...
# 280 2020-09-26  454963.0                518.0                 32.0
# 281 2020-09-27  322797.0                505.0                 45.0
# 282 2020-09-28  507882.0                506.0                 44.0
# 283 2020-09-29  535237.0                500.0                 50.0
# 284 2020-09-30  450353.0                502.0                 48.0
#
# [285 rows x 4 columns]

# %%
ny = pd.read_csv('./new_york_revised_2_14_2020.csv')
ny
# Out:
#                                                indicator     group     state  \
# 0                        Symptoms of Depressive Disorder  By State  New York
# 1                        Symptoms of Depressive Disorder  By State  New York
# 2                        Symptoms of Depressive Disorder  By State  New York
# 3                        Symptoms of Depressive Disorder  By State  New York
# 4                        Symptoms of Depressive Disorder  By State  New York
# ...                                                  ...       ...       ...
# 35779  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 35780  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 35781  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 35782  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 35783  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
#
#        subgroup              phase  time_period time_period_label  \
# 0      New York                  1          1.0    Apr 23 - May 5
# 1      New York                  1          1.0    Apr 23 - May 5
# 2      New York                  1          1.0    Apr 23 - May 5
# 3      New York                  1          1.0    Apr 23 - May 5
# 4      New York                  1          1.0    Apr 23 - May 5
# ...         ...                ...          ...               ...
# 35779  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
# 35780  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
# 35781  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
# 35782  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
# 35783  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
#
#         time_period_start_date     time_period_end_date  value  ...  \
# 0      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# 1      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# 2      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# 3      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# 4      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# ...                        ...                      ...    ...  ...
# 35779  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
# 35780  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
# 35781  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
# 35782  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
# 35783  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
#
#        confidence_interval  quartile_range                 age CASE_RATE  \
# 0              24.6 - 33.1     24.1 - 28.7       18 - 29 years    171.46
# 1              24.6 - 33.1     24.1 - 28.7       18 - 29 years   1554.45
# 2              24.6 - 33.1     24.1 - 28.7       18 - 29 years   2529.03
# 3              24.6 - 33.1     24.1 - 28.7       18 - 29 years   2552.64
# 4              24.6 - 33.1     24.1 - 28.7       18 - 29 years   2976.74
# ...                    ...             ...                 ...       ...
# 35779          32.0 - 39.7       28.8-37.6  80 years and above  20207.72
# 35780          32.0 - 39.7       28.8-37.6  80 years and above  15941.19
# 35781          32.0 - 39.7       28.8-37.6  80 years and above   7067.11
# 35782          32.0 - 39.7       28.8-37.6  80 years and above   7477.43
# 35783          32.0 - 39.7       28.8-37.6  80 years and above   6302.86
#
#       HOSPITALIZED_RATE  DEATH_RATE        date    CASE_COUNT  \
# 0                 13.55        0.23  04-23-2020   90629.21686
# 1                153.69       12.88  04-23-2020   90629.21686
# 2                630.34      113.37  04-23-2020   90629.21686
# 3               1192.50      364.17  04-23-2020   90629.21686
# 4               1830.07      909.18  04-23-2020   90629.21686
# ...                 ...         ...         ...           ...
# 35779           1160.60       67.68  02-01-2021  224684.00000
# 35780           2540.10      476.51  02-01-2021  161559.00000
# 35781           2418.35      756.82  02-01-2021   50798.00000
# 35782           3995.12     1989.81  02-01-2021   41994.00000
# 35783            958.30      266.66  02-01-2021  525458.00000
#
#       HOSPITALIZED_COUNT   DEATH_COUNT
# 0           19942.175032   6754.809134
# 1           19942.175032   6754.809134
# 2           19942.175032   6754.809134
# 3           19942.175032   6754.809134
# 4           19942.175032   6754.809134
# ...                  ...           ...
# 35779       13326.000000    794.000000
# 35780       25652.000000   4800.000000
# 35781       17383.000000   5440.000000
# 35782       22437.000000  11175.000000
# 35783       79892.000000  22231.000000
#
# [35784 rows x 22 columns]

# %%
ny['date']= pd.to_datetime(ny['date'])

# %%
ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35784 entries, 0 to 35783
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   indicator               35784 non-null  object
#  1   group                   35784 non-null  object
#  2   state                   35784 non-null  object
#  3   subgroup                35784 non-null  object
#  4   phase                   35784 non-null  object
#  5   time_period             35784 non-null  float64
#  6   time_period_label       35784 non-null  object
#  7   time_period_start_date  35784 non-null  object
#  8   time_period_end_date    35784 non-null  object
#  9   value                   35784 non-null  float64
#  10  lowci                   35784 non-null  float64
#  11  highci                  35784 non-null  float64
#  12  confidence_interval     35784 non-null  object
#  13  quartile_range          35784 non-null  object
#  14  age                     35784 non-null  object
#  15  CASE_RATE               35784 non-null  float64
#  16  HOSPITALIZED_RATE       35784 non-null  float64
#  17  DEATH_RATE              33957 non-null  float64
#  18  date                    35784 non-null  datetime64[ns]
#  19  CASE_COUNT              35784 non-null  float64
#  20  HOSPITALIZED_COUNT      35784 non-null  float64
#  21  DEATH_COUNT             35784 non-null  float64
# dtypes: datetime64[ns](1), float64(10), object(11)
# memory usage: 6.0+ MB

# %%
fin = pd.merge(ny, dates, on='date', how='inner')
fin
# Out:
#                                                indicator     group     state  \
# 0                        Symptoms of Depressive Disorder  By State  New York
# 1                        Symptoms of Depressive Disorder  By State  New York
# 2                        Symptoms of Depressive Disorder  By State  New York
# 3                        Symptoms of Depressive Disorder  By State  New York
# 4                        Symptoms of Depressive Disorder  By State  New York
# ...                                                  ...       ...       ...
# 35779  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 35780  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 35781  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 35782  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 35783  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
#
#        subgroup              phase  time_period time_period_label  \
# 0      New York                  1          1.0    Apr 23 - May 5
# 1      New York                  1          1.0    Apr 23 - May 5
# 2      New York                  1          1.0    Apr 23 - May 5
# 3      New York                  1          1.0    Apr 23 - May 5
# 4      New York                  1          1.0    Apr 23 - May 5
# ...         ...                ...          ...               ...
# 35779  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
# 35780  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
# 35781  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
# 35782  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
# 35783  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
#
#         time_period_start_date     time_period_end_date  value  ...  \
# 0      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# 1      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# 2      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# 3      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# 4      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# ...                        ...                      ...    ...  ...
# 35779  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
# 35780  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
# 35781  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
# 35782  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
# 35783  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
#
#        CASE_RATE  HOSPITALIZED_RATE DEATH_RATE       date    CASE_COUNT  \
# 0         171.46              13.55       0.23 2020-04-23   90629.21686
# 1        1554.45             153.69      12.88 2020-04-23   90629.21686
# 2        2529.03             630.34     113.37 2020-04-23   90629.21686
# 3        2552.64            1192.50     364.17 2020-04-23   90629.21686
# 4        2976.74            1830.07     909.18 2020-04-23   90629.21686
# ...          ...                ...        ...        ...           ...
# 35779   20207.72            1160.60      67.68 2021-02-01  224684.00000
# 35780   15941.19            2540.10     476.51 2021-02-01  161559.00000
# 35781    7067.11            2418.35     756.82 2021-02-01   50798.00000
# 35782    7477.43            3995.12    1989.81 2021-02-01   41994.00000
# 35783    6302.86             958.30     266.66 2021-02-01  525458.00000
#
#        HOSPITALIZED_COUNT   DEATH_COUNT    counts sentiment__negative  \
# 0            19942.175032   6754.809134  295066.0               500.0
# 1            19942.175032   6754.809134  295066.0               500.0
# 2            19942.175032   6754.809134  295066.0               500.0
# 3            19942.175032   6754.809134  295066.0               500.0
# 4            19942.175032   6754.809134  295066.0               500.0
# ...                   ...           ...       ...                 ...
# 35779        13326.000000    794.000000  419169.0               501.0
# 35780        25652.000000   4800.000000  419169.0               501.0
# 35781        17383.000000   5440.000000  419169.0               501.0
# 35782        22437.000000  11175.000000  419169.0               501.0
# 35783        79892.000000  22231.000000  419169.0               501.0
#
#        sentiment__positive
# 0                     50.0
# 1                     50.0
# 2                     50.0
# 3                     50.0
# 4                     50.0
# ...                    ...
# 35779                 49.0
# 35780                 49.0
# 35781                 49.0
# 35782                 49.0
# 35783                 49.0
#
# [35784 rows x 25 columns]

# %%
fin.to_csv('./new_york.csv', index=False)

# %%
df.sample(n=15).drop_duplicates(subset='gram')
# Out:
#                               gram  counts                date
# 542              risks coronavirus   495.0      April 24, 2020
# 514  health protection coronavirus   224.0        May 24, 2020
# 501      prophylaxis therapy covid   217.0       June 30, 2020
# 24               surpassed 200 000  1033.0     August 13, 2020
# 84             focus virus mankind   598.0       July 26, 2020
# 77                     covid 19 em   496.0     August 01, 2020
# 490                 el coronavirus   497.0      April 25, 2020
# 103               muertes covid 19   694.0       June 16, 2020
# 294                      need know   778.0        May 13, 2020
# 346                 covid 19 world   267.0       June 24, 2020
# 31           theatres music amidst  1211.0       June 17, 2020
# 276                        one day   785.0        May 05, 2020
# 132             contagios covid 19   551.0  September 08, 2020
# 120            back trump comments   570.0       July 05, 2020
# 325        accept election results   308.0       July 19, 2020

# %%
import mysql.connector
import pandas as pd
from mysql.connector import errorcode

def callDB(query):

    try: 
        mydb = mysql.connector.connect(
            host="localhost",
            user="root",
            password="Chris@164",
            database="world"
            )
        
        mycursor = mydb.cursor()

        mycursor.execute(query)

        myresult = mycursor.fetchall()

        for x in myresult:
            print(x) 

        #Store query result in Pandas dataframe
        df = pd.read_sql(query, con=mydb)

    except mysql.connector.Error as e:    
        print(e)
        print("done")

    return df

country_and_region = "select country, region, sum(population) as population from country groupby by country order by name;"
official_languages_of_country = "select continent, sum(population) as population, sum(SurfaceArea) as SurfaceArea, sum(LifeExpectancy) as LifeExpectancy, sum(GNP) as GNP from country group by continent order by continent;"

#y1 = callDB(country_and_region)
x1 = callDB(country_and_region)
# Out:
# 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'by country order by name' at line 1
# done
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-427-f74a4357bb62> in <module>
#      35
#      36 #y1 = callDB(country_and_region)
# ---> 37 x1 = callDB(country_and_region)
#
# <ipython-input-427-f74a4357bb62> in callDB(query)
#      29         print("done")
#      30
# ---> 31     return df
#      32
#      33 country_and_region = "select country, region, sum(population) as population from country groupby by country order by name;"
#
# UnboundLocalError: local variable 'df' referenced before assignment

# %%
import pymysql

# %%
import pymongo

# %%
fin
# Out:
#                                                indicator     group     state  \
# 0                        Symptoms of Depressive Disorder  By State  New York
# 1                        Symptoms of Depressive Disorder  By State  New York
# 2                        Symptoms of Depressive Disorder  By State  New York
# 3                        Symptoms of Depressive Disorder  By State  New York
# 4                        Symptoms of Depressive Disorder  By State  New York
# ...                                                  ...       ...       ...
# 35779  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 35780  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 35781  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 35782  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
# 35783  Symptoms of Anxiety Disorder or Depressive Dis...  By State  New York
#
#        subgroup              phase  time_period time_period_label  \
# 0      New York                  1          1.0    Apr 23 - May 5
# 1      New York                  1          1.0    Apr 23 - May 5
# 2      New York                  1          1.0    Apr 23 - May 5
# 3      New York                  1          1.0    Apr 23 - May 5
# 4      New York                  1          1.0    Apr 23 - May 5
# ...         ...                ...          ...               ...
# 35779  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
# 35780  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
# 35781  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
# 35782  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
# 35783  New York  3 (Jan 6 � Feb 1)         23.0    Jan 20 - Feb 1
#
#         time_period_start_date     time_period_end_date  value  ...  \
# 0      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# 1      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# 2      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# 3      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# 4      2020-04-23T00:00:00.000  2020-05-05T00:00:00.000   28.7  ...
# ...                        ...                      ...    ...  ...
# 35779  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
# 35780  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
# 35781  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
# 35782  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
# 35783  2021-01-20T00:00:00.000  2021-02-01T00:00:00.000   35.8  ...
#
#        HOSPITALIZED_RATE  DEATH_RATE       date    CASE_COUNT  \
# 0                  13.55        0.23 2020-04-23   90629.21686
# 1                 153.69       12.88 2020-04-23   90629.21686
# 2                 630.34      113.37 2020-04-23   90629.21686
# 3                1192.50      364.17 2020-04-23   90629.21686
# 4                1830.07      909.18 2020-04-23   90629.21686
# ...                  ...         ...        ...           ...
# 35779            1160.60       67.68 2021-02-01  224684.00000
# 35780            2540.10      476.51 2021-02-01  161559.00000
# 35781            2418.35      756.82 2021-02-01   50798.00000
# 35782            3995.12     1989.81 2021-02-01   41994.00000
# 35783             958.30      266.66 2021-02-01  525458.00000
#
#       HOSPITALIZED_COUNT   DEATH_COUNT    counts  sentiment__negative  \
# 0           19942.175032   6754.809134  295066.0                499.0
# 1           19942.175032   6754.809134  295066.0                499.0
# 2           19942.175032   6754.809134  295066.0                499.0
# 3           19942.175032   6754.809134  295066.0                499.0
# 4           19942.175032   6754.809134  295066.0                499.0
# ...                  ...           ...       ...                  ...
# 35779       13326.000000    794.000000  419169.0                501.0
# 35780       25652.000000   4800.000000  419169.0                501.0
# 35781       17383.000000   5440.000000  419169.0                501.0
# 35782       22437.000000  11175.000000  419169.0                501.0
# 35783       79892.000000  22231.000000  419169.0                501.0
#
#       sentiment__neutral  sentiment__positive
# 0                    1.0                 50.0
# 1                    1.0                 50.0
# 2                    1.0                 50.0
# 3                    1.0                 50.0
# 4                    1.0                 50.0
# ...                  ...                  ...
# 35779                0.0                 49.0
# 35780                0.0                 49.0
# 35781                0.0                 49.0
# 35782                0.0                 49.0
# 35783                0.0                 49.0
#
# [35784 rows x 26 columns]
